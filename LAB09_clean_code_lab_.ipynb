# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamempor/GQS--CALVETTI/blob/main/LAB09_clean_code_lab_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pylint black
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.0/536.0 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 30.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 6.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# Exercício 1

# %%
def f(a, b):
  return a*b + (a+b)

# %% [markdown]
# Refatoração

# %%
def calcular_valor_total(preco, quatidade):
  return preco* quantidade + (preco + quantidade)

# %% [markdown]
# Exercicio 2

# %%
def aplicar_desconto_a (preco): return preco * 0.9
def aplicar_desconto_b (preco): return preco * 0.9

# %% [markdown]
# Refatoração

# %%
def aplicar_desconto (preco, taxa= 0.9):
  return preco * taxa

# %% [markdown]
# Exercicio 3

# %%
def relatorio(vendas):
  total = sum(vendas)
  media = total / len(vendas)
  print ("total:", total)
  print ("media:", media)
  print ("maior: ", max(vendas))

# %% [markdown]
# Refatoração

# %%
def calcuçar_estatisticas(vendas):
  total = sum(vendas)
  media = total / len(vendas)
  maior = max(vendas)
  return total, media, maior

  def relatorio(vendas):
    total, media, maior = calcular_estatisticas(vendas)
    print (f"total: {total}, media: {media}, maior: {maior}")

# %% [markdown]
# Exercicio 4

# %%
def calcular_bonus(salario, taxa):
  return salario * (1 + taxa)

# %% [markdown]
# Refatoração

# %%
def calcular_bonus(salario, taxa):
  """retorna o salario com bonus adicional aplicado"""
  return salario * (1+ taxa)

# %% [markdown]
# Exeercicio 5

# %%
def dividir (a, b):
  return a / b

# %% [markdown]
# Refatoração

# %%
def dividir (a, b):
  try:
    return a /b
  except ZeroDivisionError:
    return "erro: divisão por zero"

# %% [markdown]
# Exercicio 6

# %%
def aplicar_desconto(valor):
  return valor * (1 - 0.1)

# %% [markdown]
# Refatoração

# %%
TAXA_DESCONTO = 0.1
def aplicar_desconto(valor):
  return valor * (1 - TAXA_DESCONTO)

# %% [markdown]
# Exercicio 7

# %%
if not cliente == None:
  if not cliente.vip == False:
    print("vip")

# %% [markdown]
# Refatoração

# %%
if cliente is not None and cliente.vip:
    print("vip")

# %% [markdown]
# Exercicio 8

# %%
def calcular_taxa(categoria):
  taxas = {"A": 0.1, "B": 0.15}
  return taxas.get(categorria, 0.05)

# %% [markdown]
# Exerciico 9

# %%
def soma(a, b): return a + b
assert soma(2, 3) == 5

# %% [markdown]
# Exercicio 10

# %%
def analisar_lista(valores):
  return{
      "maior": max(valores),
      "menor": min(valores),
      "media": sum(valores) / len
  }

# %% [markdown]
# Exercicio 11

# %%
from datetime import datetime
from pathlib import Path

DESCONTOS_FAIXA_VALOR = {
    "alto": 0.10,
    "baixo": 0.05
}
DESCONTOS_POR_CATEGORIA = {
    "A": 0.10,
    "B": 0.15,
    "C": 0.05
}
ARQUIVO_RELATORIO = Path("relatorio.txt")

def calcular_desconto_por_valor(valor: float) -> float:
  if valor > 1000:
    return * (1 - DESCONTOS_FAIXA_VALOR["alto"])
  return valor * (1- DESCONTOS_FAIXA_VALOR["baixo"])

  def calcular_total_compras(valore: list[float]) -> float:
     return sum(valores)

     def pbter_taxa_categoria(categoria: str) -> float:
       return DESCONTOS_POR_CATEGORIA.get(categoria.upper(), 0.05)

       def calcular_valor_final(total: float, categoria: str) -> float:
         valor_descontado = calcular_desconto_por_valor(total)
         taxa_categoria = obter_taxa_categoria(categoria)
         return valor_descontado * (1 - taxa_categoria)

         def gerar_relatorio(clientes: list[dict]) -> list[dict]:
          relaatorio = []
          for cliente in cliente:
            nome = cliente["n"]
            categoria = cliente ["c"]
            total = calcular_total_compras (cliente["v"])
            valor_final = calcular_valor_final(total, categoria)

            registro = {
                "nome": nome,
                "categoria": categoria,
                "total": total,
                "valor_final": valor_final,
                "data": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            }
            relatorio.append(registro)
            exibir_registro(registro)
          salvar_relatorio(relatorio)
          retun relatorio

          def exibir_registro(registro: dict) -> None:
            print(f"Cliente: {registro['nome']}") | Categoria: {registro['categoria']}")
            print(f"Total de Compras: R$ {registro['total']:.2f}")
            print(f"Valor Final (com descontos): R$ {registro['valor_final']:.2f}")
            print(f"Data de Processamento: {registro['data']}")
            print("-" * 50)

            def salvar_relatorio(relatorio: list[dict]) -> None:
              try:
                with open (ARQUIVO_RELATORIO, "w", encoding= "utf-8") as arquivo:
                  for item, in relatorio:
                    linha = f"{item['nome']}: R$ {item['valor_final']:.2f}\n"
                    arquivo.write(linha)
              print(f"\nRelatorio salvo com sucesso em: {ARQUIVO_RELATORIO.resolve()}")
          except OSError as erro:
            print(f"Erro ao salvar relatorio: {erro}")

            def main():
              clientes = [
                  {"n": "João", "c": "A", "v":[100, 200, 300]},
                  {"n": "Maria", "c": "B", "v":[400, 500]},
                  {"n": "Pedro", "c": "C", "v":[50, 25, 75]}
              ]
              gerar_relatorio(clientes)

              if __name__ == "__main__":
                main()
